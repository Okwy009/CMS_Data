# %%
# Importing Libraries
import pandas as pd
import matplotlib.pyplot as plt 
import ast
import seaborn as sns
import numpy as np

# Loading Dataset
df_sn = pd.read_csv(
    'C:/Users/hp/Downloads/Skilled_Nursing_Facility_Quality_Reporting_Program_Provider_Data_Aug2024.csv', 
    encoding = 'ISO-8859-1',
    low_memory = False
)

# %%
# Display the first few rows to understand the data structure
df_sn.head()
# Out:
#   CMS Certification Number (CCN)             Provider Name  \
# 0                         015009  BURNS NURSING HOME, INC.
# 1                         015009  BURNS NURSING HOME, INC.
# 2                         015009  BURNS NURSING HOME, INC.
# 3                         015009  BURNS NURSING HOME, INC.
# 4                         015009  BURNS NURSING HOME, INC.
#
#          Address Line 1     City/Town State  ZIP Code County/Parish  \
# 0  701 MONROE STREET NW  RUSSELLVILLE    AL     35653      Franklin
# 1  701 MONROE STREET NW  RUSSELLVILLE    AL     35653      Franklin
# 2  701 MONROE STREET NW  RUSSELLVILLE    AL     35653      Franklin
# 3  701 MONROE STREET NW  RUSSELLVILLE    AL     35653      Franklin
# 4  701 MONROE STREET NW  RUSSELLVILLE    AL     35653      Franklin
#
#   Telephone Number  CMS Region               Measure Code  \
# 0    (256)332-4110           4       S_001_03_DENOMINATOR
# 1    (256)332-4110           4         S_001_03_NUMERATOR
# 2    (256)332-4110           4          S_001_03_OBS_RATE
# 3    (256)332-4110           4  S_004_01_PPR_PD_COMP_PERF
# 4    (256)332-4110           4        S_004_01_PPR_PD_OBS
#
#                                  Score Footnote  Start Date    End Date  \
# 0                                   73        -  10/01/2022  09/30/2023
# 1                                   73        -  10/01/2022  09/30/2023
# 2                                100.0        -  10/01/2022  09/30/2023
# 3  No Different than the National Rate        -  10/01/2020  09/30/2022
# 4                                 3.41        -  10/01/2020  09/30/2022
#
#   Measure Date Range                                      LOCATION1
# 0                  -  701 MONROE STREET NW, RUSSELLVILLE, AL, 35653
# 1                  -  701 MONROE STREET NW, RUSSELLVILLE, AL, 35653
# 2                  -  701 MONROE STREET NW, RUSSELLVILLE, AL, 35653
# 3                  -  701 MONROE STREET NW, RUSSELLVILLE, AL, 35653
# 4                  -  701 MONROE STREET NW, RUSSELLVILLE, AL, 35653

# %%
df_sn.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 800550 entries, 0 to 800549
# Data columns (total 16 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   CMS Certification Number (CCN)  800550 non-null  object
#  1   Provider Name                   800550 non-null  object
#  2   Address Line 1                  800550 non-null  object
#  3   City/Town                       800550 non-null  object
#  4   State                           800550 non-null  object
#  5   ZIP Code                        800550 non-null  int64
#  6   County/Parish                   800550 non-null  object
#  7   Telephone Number                800550 non-null  object
#  8   CMS Region                      800550 non-null  int64
#  9   Measure Code                    800550 non-null  object
#  10  Score                           800550 non-null  object
#  11  Footnote                        800550 non-null  object
#  12  Start Date                      800550 non-null  object
#  13  End Date                        800550 non-null  object
#  14  Measure Date Range              800550 non-null  object
#  15  LOCATION1                       800550 non-null  object
# dtypes: int64(2), object(14)
# memory usage: 97.7+ MB

# %%
# Convert 'Score' to numeric, setting errors='coerce' to handle non-numeric values
df_sn['Score'] = pd.to_numeric(df_sn['Score'], errors='coerce')

# Convert 'Start Date' and 'End Date' to datetime
df_sn['Start Date'] = pd.to_datetime(df_sn['Start Date'], errors='coerce')
df_sn['End Date'] = pd.to_datetime(df_sn['End Date'], errors='coerce')
df_sn
# Out:
#        CMS Certification Number (CCN)                  Provider Name  \
# 0                              015009       BURNS NURSING HOME, INC.
# 1                              015009       BURNS NURSING HOME, INC.
# 2                              015009       BURNS NURSING HOME, INC.
# 3                              015009       BURNS NURSING HOME, INC.
# 4                              015009       BURNS NURSING HOME, INC.
# ...                               ...                            ...
# 800545                         745040  THE SARAH ROBERTS FRENCH HOME
# 800546                         745040  THE SARAH ROBERTS FRENCH HOME
# 800547                         745040  THE SARAH ROBERTS FRENCH HOME
# 800548                         745040  THE SARAH ROBERTS FRENCH HOME
# 800549                         745040  THE SARAH ROBERTS FRENCH HOME
#
#               Address Line 1     City/Town State  ZIP Code County/Parish  \
# 0       701 MONROE STREET NW  RUSSELLVILLE    AL     35653      Franklin
# 1       701 MONROE STREET NW  RUSSELLVILLE    AL     35653      Franklin
# 2       701 MONROE STREET NW  RUSSELLVILLE    AL     35653      Franklin
# 3       701 MONROE STREET NW  RUSSELLVILLE    AL     35653      Franklin
# 4       701 MONROE STREET NW  RUSSELLVILLE    AL     35653      Franklin
# ...                      ...           ...   ...       ...           ...
# 800545        1315 TEXAS AVE   SAN ANTONIO    TX     78201         Bexar
# 800546        1315 TEXAS AVE   SAN ANTONIO    TX     78201         Bexar
# 800547        1315 TEXAS AVE   SAN ANTONIO    TX     78201         Bexar
# 800548        1315 TEXAS AVE   SAN ANTONIO    TX     78201         Bexar
# 800549        1315 TEXAS AVE   SAN ANTONIO    TX     78201         Bexar
#
#        Telephone Number  CMS Region               Measure Code   Score  \
# 0         (256)332-4110           4       S_001_03_DENOMINATOR   73.00
# 1         (256)332-4110           4         S_001_03_NUMERATOR   73.00
# 2         (256)332-4110           4          S_001_03_OBS_RATE  100.00
# 3         (256)332-4110           4  S_004_01_PPR_PD_COMP_PERF     NaN
# 4         (256)332-4110           4        S_004_01_PPR_PD_OBS    3.41
# ...                 ...         ...                        ...     ...
# 800545    (210)736-4238           6         S_040_01_NUMERATOR     NaN
# 800546    (210)736-4238           6          S_040_01_OBS_RATE     NaN
# 800547    (210)736-4238           6       S_041_01_DENOMINATOR     NaN
# 800548    (210)736-4238           6         S_041_01_NUMERATOR     NaN
# 800549    (210)736-4238           6          S_041_01_OBS_RATE     NaN
#
#        Footnote Start Date   End Date Measure Date Range  \
# 0             - 2022-10-01 2023-09-30                  -
# 1             - 2022-10-01 2023-09-30                  -
# 2             - 2022-10-01 2023-09-30                  -
# 3             - 2020-10-01 2022-09-30                  -
# 4             - 2020-10-01 2022-09-30                  -
# ...         ...        ...        ...                ...
# 800545       10 2023-07-01 2023-09-30                  -
# 800546       10 2023-07-01 2023-09-30                  -
# 800547       10 2022-10-01 2023-03-31                  -
# 800548       10 2022-10-01 2023-03-31                  -
# 800549       10 2022-10-01 2023-03-31                  -
#
#                                             LOCATION1
# 0       701 MONROE STREET NW, RUSSELLVILLE, AL, 35653
# 1       701 MONROE STREET NW, RUSSELLVILLE, AL, 35653
# 2       701 MONROE STREET NW, RUSSELLVILLE, AL, 35653
# 3       701 MONROE STREET NW, RUSSELLVILLE, AL, 35653
# 4       701 MONROE STREET NW, RUSSELLVILLE, AL, 35653
# ...                                               ...
# 800545         1315 TEXAS AVE, SAN ANTONIO, TX, 78201
# 800546         1315 TEXAS AVE, SAN ANTONIO, TX, 78201
# 800547         1315 TEXAS AVE, SAN ANTONIO, TX, 78201
# 800548         1315 TEXAS AVE, SAN ANTONIO, TX, 78201
# 800549         1315 TEXAS AVE, SAN ANTONIO, TX, 78201
#
# [800550 rows x 16 columns]

# %%
# If 'Score' is numeric, fill missing values with the mean
df_sn['Score'] = pd.to_numeric(df_sn['Score'], errors='coerce')
df_sn['Score'].fillna(df_sn['Score'].mean())

df_sn.isnull().sum()
# Out:
# CMS Certification Number (CCN)    0
# Provider Name                     0
# Address Line 1                    0
# City/Town                         0
# State                             0
# ZIP Code                          0
# County/Parish                     0
# Telephone Number                  0
# CMS Region                        0
# Measure Code                      0
# Score                             0
# Footnote                          0
# Start Date                        0
# End Date                          0
# Measure Date Range                0
# LOCATION1                         0
# dtype: int64

# %%
# Renaming the CCN column to PROVNUM
df_sn.rename(columns={'CMS Certification Number (CCN)': 'PROVNUM'}, inplace=True)
df_sn.describe()
# Out:
#             ZIP Code     CMS Region          Score  \
# count  800550.000000  800550.000000  800550.000000
# mean    50333.836830       5.190422      56.747040
# min       660.000000       1.000000     -12.400000
# 25%     29732.000000       4.000000      11.000000
# 50%     48532.000000       5.000000      50.000000
# 75%     73024.000000       7.000000      64.000000
# max     99929.000000      10.000000    2211.000000
# std     26866.884171       2.249190      70.790824
#
#                           Start Date                       End Date
# count                         800550                         800550
# mean   2022-01-25 13:19:59.999999744  2023-04-17 08:53:20.000001024
# min              2020-10-01 00:00:00            2022-09-30 00:00:00
# 25%              2020-10-01 00:00:00            2022-09-30 00:00:00
# 50%              2022-10-01 00:00:00            2023-09-30 00:00:00
# 75%              2022-10-01 00:00:00            2023-09-30 00:00:00
# max              2023-07-01 00:00:00            2023-09-30 00:00:00
# std                              NaN                            NaN

# %%
# Save the cleaned dataframe
df_sn.to_csv('C:/Users/hp/Downloads/Cleaned_Skilled_Nursing_Facility_Quality_Reporting_Program_Provider_Data_Aug2024.csv', index=False)

# %% [markdown]
# ### Full Code

# %%
df_sn = pd.read_csv(
    'C:/Users/hp/Downloads/Skilled_Nursing_Facility_Quality_Reporting_Program_Provider_Data_Aug2024.csv'
)
df_sn['Score'] = pd.to_numeric(df_sn['Score'], errors='coerce')
df_sn['Start Date'] = pd.to_datetime(df_sn['Start Date'], errors='coerce')
df_sn['End Date'] = pd.to_datetime(df_sn['End Date'], errors='coerce')
df_sn['Score'] = pd.to_numeric(df_sn['Score'], errors='coerce')
df_sn['Score'].fillna(df_sn['Score'].mean())
df_sn.rename(columns={'CMS Certification Number (CCN)': 'PROVNUM'}, inplace=True)
df_sn.to_csv('C:/Users/hp/Downloads/Cleaned_Skilled_Nursing_Facility_Quality_Reporting_Program_Provider_Data_Aug2024.csv', index=False)
